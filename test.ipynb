# %%
import torch
print(torch.cuda.current_device())
print(torch.cuda.get_device_name(0))
print(torch.__version__)
# Out:
# 0
# NVIDIA GeForce RTX 4090
# 2.5.1+cu124

# %%
#!/bin/bash

# 激活环境

base_model_path="/mnt/sda/llmfact/LLaMA-Factory/Meta-Llama-3-8B-Instruct"

for mixing in [1.0, 0.5, 0.25, 0.125]:
    output_dir=f"/mnt/sda/llmfact/LLaMA-Factory/spa_exp/llama3-8b/distill/mix_{mixing}"

    # !CUDA_VISIBLE_DEVICES=3 llamafactory-cli train \
            examples/train_lora/llama3_lora_dpo.yaml \
            --output_dir=${output_dir} \
            --pref_loss=distill \
            --decouple_denoising=${mixing} \
            --confidence_dir=${output_dir} \
            --model_name_or_path=${base_model_path}
# Out:
# Traceback (most recent call last):
#   File "/home/nusbac/miniconda3/envs/llama_factory/bin/llamafactory-cli", line 8, in <module>
#     sys.exit(main())
#   File "/mnt/sda/llmfact/LLaMA-Factory/src/llamafactory/cli.py", line 112, in main
#     run_exp()
#   File "/mnt/sda/llmfact/LLaMA-Factory/src/llamafactory/train/tuner.py", line 92, in run_exp
#     _training_function(config={"args": args, "callbacks": callbacks})
#   File "/mnt/sda/llmfact/LLaMA-Factory/src/llamafactory/train/tuner.py", line 52, in _training_function
#     model_args, data_args, training_args, finetuning_args, generating_args = get_train_args(args)
#   File "/mnt/sda/llmfact/LLaMA-Factory/src/llamafactory/hparams/parser.py", line 182, in get_train_args
#     model_args, data_args, training_args, finetuning_args, generating_args = _parse_train_args(args)
#   File "/mnt/sda/llmfact/LLaMA-Factory/src/llamafactory/hparams/parser.py", line 162, in _parse_train_args
#     return _parse_args(parser, args)
# ...
